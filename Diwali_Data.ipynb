# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Diwali Sales Data.csv",encoding='unicode_escape')

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0  \
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders
# 0     Maharashtra   Western       Healthcare             Auto       1  \
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail(6)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status
# 11245  1004140    Bertelson  P00057442      F     26-35   31               1  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount
# 11245           Delhi   Central     Aviation           Office       2   381.0  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
r,c=df.shape

# %%
r
# Out:
# 11251

# %%
c
# Out:
# 15

# %%
print('Total row in present data is',df.shape[0])
print('Total columns in present data is',df.shape[1])
# Out:
# Total row in present data is 11251
# Total columns in present data is 15

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# Status              float64
# unnamed1            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(["Status","unnamed1"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age
# 0        False      False       False   False      False  False  \
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders
# 0               False  False  False       False             False   False  \
# ...

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()*100/len(df)
# Out:
# User_ID             0.000000
# Cust_name           0.000000
# Product_ID          0.000000
# Gender              0.000000
# Age Group           0.000000
# Age                 0.000000
# Marital_Status      0.000000
# State               0.000000
# Zone                0.000000
# Occupation          0.000000
# Product_Category    0.000000
# Orders              0.000000
# Amount              0.106657
# dtype: float64

# %%
t=df.isnull().values.any()
print('There are present null value show boll answer data is null',t)
# Out:
# There are present null value show boll answer data is null True

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int32
# dtype: object

# %%
df.rename(columns={"Marital_Status":"Marredpeople"})# if you want rename columns df.rename(columns={"Marital_Status":"Marredpeople"},inplace=True)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marredpeople
# 0      1002903    Sanskriti  P00125942      F     26-35   28             0  \
# 1      1000732       Kartik  P00110942      F     26-35   35             1
# 2      1001990        Bindu  P00118542      F     26-35   35             1
# 3      1001425       Sudevi  P00237842      M      0-17   16             0
# 4      1000588         Joni  P00057942      M     26-35   28             1
# ...        ...          ...        ...    ...       ...  ...           ...
# 11246  1000695      Manning  P00296942      M     18-25   19             1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33             0
# 11248  1001209        Oshin  P00201342      F     36-45   40             0
# 11249  1004023       Noonan  P00059442      M     36-45   37             0
# 11250  1002744      Brumley  P00281742      F     18-25   19             0
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df.describe(include='all')
# Out:
#              User_ID Cust_name Product_ID Gender Age Group           Age
# count   1.123900e+04     11239      11239  11239     11239  11239.000000  \
# unique           NaN      1250       2350      2         7           NaN
# top              NaN  Vishakha  P00265242      F     26-35           NaN
# freq             NaN        42         53   7832      4541           NaN
# mean    1.003004e+06       NaN        NaN    NaN       NaN     35.410357
# std     1.716039e+03       NaN        NaN    NaN       NaN     12.753866
# min     1.000001e+06       NaN        NaN    NaN       NaN     12.000000
# 25%     1.001492e+06       NaN        NaN    NaN       NaN     27.000000
# 50%     1.003064e+06       NaN        NaN    NaN       NaN     33.000000
# 75%     1.004426e+06       NaN        NaN    NaN       NaN     43.000000
# max     1.006040e+06       NaN        NaN    NaN       NaN     92.000000
#
#         Marital_Status          State     Zone Occupation    Product_Category
# ...

# %%
df.keys()
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(data=df,x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
t=sns.countplot(data=df,x='Gender')
for o in t.containers:
    t.bar_label(o)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    7832
# M    3407
# Name: count, dtype: int64

# %%
data1=df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by=['Gender'],ascending=False)
data1
# Out:
#   Gender    Amount
# 1      M  31913276
# 0      F  74335853

# %%
sns.barplot(data=data1,x='Gender',y='Amount',hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
# from above we can see that most of the buyers are female and purchasing power of females are grater than man

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(data=df,x='Age Group',hue='Gender')
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
adata=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False)
adata
# Out:
#   Age Group    Amount
# 2     26-35  42613442
# 3     36-45  22144994
# 1     18-25  17240732
# 4     46-50   9207844
# 5     51-55   8261477
# 6       55+   4080987
# 0      0-17   2699653

# %%
sns.barplot(data=adata,x='Age Group',y='Amount')
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
# From above grapha can see that most buyers are age group 26-35 yrs female

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
plt.figure(figsize=(16,5))
sns.countplot(data=df,x='State')
plt.xticks(rotation=70)
plt.show()

# %%
plt.figure(figsize=(16,5))
d=sns.countplot(data=df,x='State')
for p in d.containers:
    d.bar_label(p)
plt.xticks(rotation=70)
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ddf=df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by=['Orders'],ascending=False).head(10)
ddf
# Out:
#                State  Orders
# 14     Uttar Pradesh    4807
# 10       Maharashtra    3810
# 7          Karnataka    3240
# 2              Delhi    2740
# 9     Madhya Pradesh    2252
# 0     Andhra Pradesh    2051
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1066

# %%
sns.set(rc={'figure.figsize':(16,5)})
sns.barplot(data=ddf,x='State',y='Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
#There are Top State orders show

# %%
amt=df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False).head(10)
amt
# Out:
#                State    Amount
# 14     Uttar Pradesh  19374968
# 10       Maharashtra  14427543
# 7          Karnataka  13523540
# 2              Delhi  11603818
# 9     Madhya Pradesh   8101142
# 0     Andhra Pradesh   8037146
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3946082

# %%
sns.barplot(data=amt,x='State',y='Amount')
plt.title('There are show State amount')
plt.xlabel('There is show State',fontsize=15)
plt.ylabel('There is show Amount',fontsize=15)
plt.show()

# %%
#There are Top Amount orders show

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='Marital_Status')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
mdata=df.groupby(['Marital_Status'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False)
mdata
# Out:
#    Marital_Status    Amount
# 0               0  62125384
# 1               1  44123745

# %%
sns.set(rc={"figure.figsize":(10,5)})
sns.barplot(data=mdata,x='Marital_Status',y='Amount')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
ma=df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False)
ma
# Out:
#    Marital_Status Gender    Amount
# 0               0      F  43786646
# 2               1      F  30549207
# 1               0      M  18338738
# 3               1      M  13574538

# %%
sns.barplot(data=ma,x='Marital_Status',y='Amount',hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
plt.figure(figsize=(16,5))
sns.countplot(data=df,x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
odata=df.groupby(['Occupation'],as_index=False)['Orders'].sum().sort_values(by=['Orders'],ascending=False)
odata
# Out:
#          Occupation  Orders
# 10        IT Sector    3997
# 8        Healthcare    3455
# 2          Aviation    3215
# 3           Banking    2817
# 7              Govt    2155
# 9       Hospitality    1739
# 12            Media    1596
# 1        Automobile    1371
# 11           Lawyer    1344
# 4          Chemical    1309
# 13           Retail    1270
# 6   Food Processing    1073
# 5      Construction    1025
# 14          Textile     893
# 0       Agriculture     722

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=odata,x='Occupation',y='Orders')
# Out:
# <Axes: xlabel='Occupation', ylabel='Orders'>

# %%
oamt=df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False)
oamt
# Out:
#          Occupation    Amount
# 10        IT Sector  14755079
# 8        Healthcare  13034586
# 2          Aviation  12602298
# 3           Banking  10770610
# 7              Govt   8517212
# 9       Hospitality   6376405
# 12            Media   6295832
# 1        Automobile   5368596
# 4          Chemical   5297436
# 11           Lawyer   4981665
# 13           Retail   4783170
# 6   Food Processing   4070670
# 5      Construction   3597511
# 14          Textile   3204972
# 0       Agriculture   2593087

# %%
sns.barplot(data=oamt,x='Occupation',y='Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
df.keys()
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
pcat=df.groupby(['Product_Category'],as_index=False)['Orders'].sum().sort_values(by=['Orders'],ascending=False)
pcat
# Out:
#          Product_Category  Orders
# 3      Clothing & Apparel    6634
# 6                    Food    6110
# 5   Electronics & Gadgets    5226
# 7        Footwear & Shoes    2646
# 11        Household items    1331
# 1                  Beauty    1086
# 9            Games & Toys     940
# 8               Furniture     889
# 14        Sports Products     870
# 13               Pet Care     536
# 15             Stationery     281
# 12                 Office     261
# 2                   Books     245
# 0                    Auto     239
# 4                   Decor     235
# 17             Veterinary     206
# 16             Tupperware     166
# 10     Hand & Power Tools      80

# %%
sns.set(rc={'figure.figsize':(25,7)})
sns.barplot(data=pcat,x='Product_Category',y='Orders')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Orders'>

# %%
acat=df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by=['Amount'],ascending=False)
acat
# Out:
#          Product_Category    Amount
# 6                    Food  33933883
# 3      Clothing & Apparel  16495019
# 5   Electronics & Gadgets  15643846
# 7        Footwear & Shoes  15575209
# 8               Furniture   5440051
# 9            Games & Toys   4331694
# 14        Sports Products   3635933
# 1                  Beauty   1959484
# 0                    Auto   1958609
# 15             Stationery   1676051
# 11        Household items   1569337
# 16             Tupperware   1155642
# 2                   Books   1061478
# 4                   Decor    730360
# 13               Pet Care    482277
# 10     Hand & Power Tools    405618
# 17             Veterinary    112702
# 12                 Office     81936

# %%
sns.set(rc={'figure.figsize':(25,6)})
sns.barplot(data=acat,x='Product_Category',y='Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
data.columns
# Out:
# Index(['Gender', 'Amount'], dtype='object')
